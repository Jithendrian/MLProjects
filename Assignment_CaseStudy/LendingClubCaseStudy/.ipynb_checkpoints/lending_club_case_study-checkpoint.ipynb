# %%
#import required libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
import re
from matplotlib.colors import LinearSegmentedColormap

#suppress warnings thrown by the libraries imported
warnings.filterwarnings('ignore')

#for now we are converting every column to object type and we will be changing the columns as per requirement
#this is done because it causes issues in the analysis as a lot of irrelevant data is present.
loan = pd.read_csv('loan.csv', dtype=object)
#Print dataframe shape to get the idea of rows and columns
#Print the information of the loan dataframe
#Print the data types of the loan dataframe
print(loan.shape)
print(loan.info())
print(loan.dtypes)

#remove duplicates
loan = loan.drop_duplicates(keep='first', subset='id')
# Out:
# (39717, 111)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39717 entries, 0 to 39716
# Columns: 111 entries, id to total_il_high_credit_limit
# dtypes: object(111)
# memory usage: 33.6+ MB
# None
# id                            object
# member_id                     object
# loan_amnt                     object
# funded_amnt                   object
# funded_amnt_inv               object
#                                ...
# tax_liens                     object
# tot_hi_cred_lim               object
# total_bal_ex_mort             object
# total_bc_limit                object
# total_il_high_credit_limit    object
# Length: 111, dtype: object

# %%
#Drop following columns:

# 1. All values are null or na
loan.drop(loan.columns[loan.apply(lambda col: col.isnull().sum() / len(loan.index) >= 0.9)], inplace = True, axis = 1)
loan.info()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[377], line 4
#       1 #Drop following columns:
#       2
#       3 # 1. All values are null or na
# ----> 4 loan.drop(loan.columns[loan.apply(lambda col: col.isnull().sum() / len(loan.index) >= 0.9)], inplace = True, axis = 1)
#       5 loan.info()
#
# AttributeError: 'Index' object has no attribute 'columns'

# %%
# 2. Only contains a single value
loan.drop(loan.columns[loan.apply(lambda col: col.nunique() <= 1)], inplace = True,  axis = 1)

# %%
# 3. Irrelevant columns
behaviour_var =  [
  "delinq_2yrs",
  "earliest_cr_line",
  "inq_last_6mths",
  "open_acc",
  "pub_rec",
  "revol_bal",
  "revol_util",
  "total_acc",
  "out_prncp",
  "out_prncp_inv",
  "total_pymnt",
  "total_pymnt_inv",
  "total_rec_prncp",
  "total_rec_int",
  "total_rec_late_fee",
  "recoveries",
  "collection_recovery_fee",
  "last_pymnt_d",
  "last_pymnt_amnt",
  "last_credit_pull_d",
  'id',
  'member_id']
loan.drop(labels = behaviour_var, inplace = True, axis = 1)

other_vars = [
    'title', 
    'url', 
    'zip_code', 
    'addr_state',
    'desc',
    'emp_title',
    'mths_since_last_delinq'
]

loan.drop(labels = other_vars, inplace = True, axis = 1)

#check the shape of the cleaned dataframe
loan.shape

# %%
# null_percentage_columns = {}
# Finding out the percentage of null values in each columns
# for column in loan.columns:
#     null_values = loan[column].isnull()
#     number_of_null_values = null_values.sum()
#     percentage_of_null_values = (number_of_null_values/ total_rows) * 100
#     null_percentage_columns[column] = percentage_of_null_values
# null_percentage_columns

# %%
# '''
# First way to figure out null values
# print(loan.shape)
# total_rows = loan.shape[0]
# #find out all the null values in the column
# null_check = loan.isnull()
# null_percentage_columns = {}
# #Finding out the percentage of null values in each columns
# for column in loan.columns:
#     null_values = loan[column].isnull()
#     number_of_null_values = null_values.sum()
#     percentage_of_null_values = (number_of_null_values/ total_rows) * 100
#     null_percentage_columns[column] = percentage_of_null_values
# null_columns_to_be_removed = []
# threshold_value = 90
# for key,values in null_percentage_columns.items():
#     if values > threshold_value:
#         null_columns_to_be_removed.append(key)
# print("Columns to be removed {}", null_columns_to_be_removed)
# loan.drop(null_columns_to_be_removed, axis = 1, inplace = True)
# '''

# %%
#clean up
#remove % symbol from interest rate and revolving line utilization rate
loan['int_rate'] = loan['int_rate'].str.rstrip('%').astype('float')
#extract digit from employment length
loan = loan[~loan['emp_length'].isnull()]
loan['emp_length'] = loan['emp_length'].str.extract('(\d+)').astype('int')

#extract digits from term
loan['term'] = loan['term'].str.extract('(\d+)').astype('int')

loan['loan_status'] = loan['loan_status'].astype('category')

print(loan.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 38642 entries, 0 to 39716
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   loan_amnt             38642 non-null  object
#  1   funded_amnt           38642 non-null  object
#  2   funded_amnt_inv       38642 non-null  object
#  3   term                  38642 non-null  int32
#  4   int_rate              38642 non-null  float64
#  5   installment           38642 non-null  object
#  6   grade                 38642 non-null  object
#  7   sub_grade             38642 non-null  object
#  8   emp_length            38642 non-null  int32
#  9   home_ownership        38642 non-null  object
#  10  annual_inc            38642 non-null  object
#  11  verification_status   38642 non-null  object
#  12  issue_d               38642 non-null  object
#  13  loan_status           38642 non-null  category
#  14  purpose               38642 non-null  object
#  15  dti                   38642 non-null  object
#  16  pub_rec_bankruptcies  37945 non-null  object
# dtypes: category(1), float64(1), int32(2), object(13)
# memory usage: 4.8+ MB
# None

# %%
# Rows where loan status is current is not of much use for us as it is neither fully paid nor charged off.
# So we can remove those rows and set charged off to 1 and full paid to 0 for further analysis
loan = loan[~(loan['loan_status'] == 'Current')]

loan['loan_status'] = loan['loan_status'].apply(lambda ls : 0 if ls == 'Fully Paid' else 1)
print(loan['loan_status'].head())
# Out:
# 0    0
# 1    1
# 2    0
# 3    0
# 5    0
# Name: loan_status, dtype: int64

# %%
loan['issue_d'] = pd.to_datetime(loan['issue_d'], format='%b-%y')
loan['issue_year'] = loan['issue_d'].dt.year
loan['issue_month'] = loan['issue_d'].dt.month

# %%
#Univariate Analysis

#convert the required variables to numeric type
numeric_cols = ['loan_amnt','funded_amnt','int_rate','funded_amnt_inv','installment','annual_inc','dti','emp_length', 'pub_rec_bankruptcies']
loan[numeric_cols] = loan[numeric_cols].apply(pd.to_numeric)

# %%
loan_correlation_data = loan.corr(numeric_only=True)
fig, ax = plt.subplots(figsize=(12, 9))
sns.set(font_scale=1.1)
color_scheme = LinearSegmentedColormap.from_list('rg', ["r", "y", "g"], N=256)
sns.heatmap(loan_correlation_data,cmap = color_scheme, ax=ax, annot=True)
plt.show()

#Findings
#1. Term has positive correlation with loan status that implies, chances of default increase with the term.
#2. Interest Rate  has positive correlation with loan status that implies, chances of default increase with the increase in Interest Rate.
#3. Chances of default decreases with increase in annual income as correlation is negative. 
#4. The effect of public record bankruptcies is not much on the loan default.

# %%
loan['loan_status'].value_counts()
# Out:
# 0    32145
# 1     5399
# Name: loan_status, dtype: int64

# %%
def countplot(column):
    """
    prints distribution of values in percentages.
    plots a countplot for the provided column
    ** param column: column name
    """
    print(round(100 * loan[column].value_counts()/ loan[column].count(), 2))
    sns.countplot(data=loan, x = column)

# %%
#analysing status of loan as it's one of the most important variables
countplot('loan_status')

#Findings
#---------------------------------------------------
#almost 86 percent people has fully paid their loans
#14 percent has defaulted.
#3 percent are in the process of paying.
#---------------------------------------------------
# Out:
# 0    85.62
# 1    14.38
# Name: loan_status, dtype: float64

# %%
def remove_outliers(column, min_percentile, max_percentile):
    """
        Removes outliers from a given column
        **param column: column from which outliers should be removed
        **param min_percentile: minimum percentile above which data is consistent
        **param max_percentile: maximum percentile below which data is consistent

        ##Returns the dataframe after removing outliers from it.
    """
    max_percentile_limit = loan[column].quantile(max_percentile)
    min_percentile_limit = loan[column].quantile(min_percentile)
    return loan[((loan[column] > min_percentile_limit) & (loan[column] < max_percentile_limit))]

# %%
def describe_and_boxplot(column):
    """
    plots a count plot and prints a description
    
    **param column: column name for count plot
    """
    print(loan[column].describe())

    sns.boxplot(loan[column])
    plt.show()

# %%
#Loan Amount
describe_and_boxplot('loan_amnt')

#seems like Loan amount is already consistent and doesn't have any outliers

#findings
#1. Average Loan amount is 11119
#2. Most of the loan taken are in the range 5500 - 15000
#3. Maximum loan taken is 35000 and minimum is 500
# Out:
# count    37544.000000
# mean     11119.329986
# std       7354.098954
# min        500.000000
# 25%       5500.000000
# 50%      10000.000000
# 75%      15000.000000
# max      35000.000000
# Name: loan_amnt, dtype: float64

# %%
#Annual Income
describe_and_boxplot('annual_inc')


#Seems like data has outliers and we have to remove those outliers
loan = remove_outliers('annual_inc', 0.01, 0.99)
#After removing outliers
sns.boxplot(loan['annual_inc'])
plt.show()

#findings
#1. Average salary is 69407
#2. Maximum salary is 6000000 and minimum is 4000
#3. Most applicants have salary range between 41000 and 83000
# Out:
# count    3.754400e+04
# mean     6.940708e+04
# std      6.467698e+04
# min      4.000000e+03
# 25%      4.100000e+04
# 50%      6.000000e+04
# 75%      8.300000e+04
# max      6.000000e+06
# Name: annual_inc, dtype: float64

# %%
#Interest Rate
describe_and_boxplot('int_rate')
#Seems like interest rate doesn't have any outliers

#findings
#1. Average interest rate is 12%(approximately)
#2. Maximum interest rate is 24.4% and minimum is 5.42%
#3. Most loans have interest rate between 8.94% and 14.41%
# Out:
# count    36762.000000
# mean        11.950368
# std          3.680300
# min          5.420000
# 25%          8.940000
# 50%         11.830000
# 75%         14.410000
# max         24.400000
# Name: int_rate, dtype: float64

# %%
#Debt to income ratio(DTI)
describe_and_boxplot('dti')

#findings
#1. Average DTI is 13(approximately)
#2. Maximum DTI is 30(approximately) and minimum is 0
#3. Most applicants have DTI between 8.29 and 18.62
# Out:
# count    36762.000000
# mean        13.375227
# std          6.638618
# min          0.000000
# 25%          8.290000
# 50%         13.480000
# 75%         18.620000
# max         29.990000
# Name: dti, dtype: float64

# %%
countplot('home_ownership')

#Findings
#1. Most people who take loans are staying at rented houses(48%) or have mortgaged their houses(44%).
#2. People with no houses generally doesn't take any loans(0.01%).
# Out:
# RENT        48.12
# MORTGAGE    44.36
# OWN          7.26
# OTHER        0.26
# NONE         0.01
# Name: home_ownership, dtype: float64

# %%
countplot('verification_status')
#Findings
#1. Most of the loans taken are by verified people(25% + 31%)
#2. Non verified people loans are around 43.5%
# Out:
# Not Verified       43.46
# Verified           31.37
# Source Verified    25.17
# Name: verification_status, dtype: float64

# %%
countplot('issue_year')

#Findings
#1. Most loans were taken in the year 2011
#2. In 2007 people took least loans(Loan interest rate might be the reason for this. Maybe in 2007-2008 loan interest rates were high)
# Out:
# 2011    52.91
# 2010    29.80
# 2009    12.47
# 2008     4.17
# 2007     0.65
# Name: issue_year, dtype: float64

# %%
countplot('issue_month')
#Findings
#1. At the start of the year people generally take lesser loans
#2. At the end of the year people generally seems to take more loans.
# Out:
# 12    11.02
# 11    10.33
# 10     9.66
# 9      9.06
# 8      8.88
# 7      8.66
# 6      8.24
# 5      7.56
# 4      7.36
# 3      6.98
# 1      6.18
# 2      6.08
# Name: issue_month, dtype: float64

# %%
countplot('grade')
#Findings
#1. Grade B generally take more loans than any other grade followed by Grade A and Grade C respectively
#2. Grade F and Grade G applicants take comparatively much lesser loans.
# Out:
# B    30.31
# A    25.83
# C    20.40
# D    13.20
# E     6.93
# F     2.54
# G     0.78
# Name: grade, dtype: float64

# %%
plt.xticks(rotation = 90)
sns.set(font_scale=0.9)
countplot('sub_grade')
#Findings
#1. Grade A4, B3, A5 take almost equal amount of loans and maximum number of loans.
#2. Grade G5 applicants take least amount of loans.
# Out:
# A4    7.48
# B3    7.31
# A5    7.02
# B5    6.85
# B4    6.39
# C1    5.36
# B2    5.17
# C2    5.05
# A3    4.65
# B1    4.59
# A2    3.86
# C3    3.86
# D2    3.33
# C4    3.15
# C5    2.98
# D3    2.90
# A1    2.82
# D1    2.42
# D4    2.39
# D5    2.16
# E1    1.89
# E2    1.60
# E3    1.33
# E4    1.12
# E5    0.98
# F1    0.80
# F2    0.61
# F3    0.45
# F4    0.39
# F5    0.29
# G1    0.25
# G2    0.20
# G4    0.14
# G3    0.12
# G5    0.08
# Name: sub_grade, dtype: float64

# %%
plt.xticks(rotation = 90)
countplot('purpose')

#Findings
#1. almost 50% loans are taken to pay out existing loans.
#2. 13% loans are taken to pay credit card balances.
# Out:
# debt_consolidation    47.33
# credit_card           13.14
# other                  9.81
# home_improvement       7.33
# major_purchase         5.52
# small_business         4.52
# car                    3.83
# wedding                2.45
# medical                1.74
# moving                 1.44
# house                  0.93
# vacation               0.93
# educational            0.77
# renewable_energy       0.25
# Name: purpose, dtype: float64

# %%
countplot('emp_length')
#Findings
#1. People tend to take loans at the start i.e. 0-1 years of experience or after 10+ years of experience.
#2. for 5-9 years experienced the loans taken are least.
# Out:
# 10    22.69
# 1     20.22
# 2     11.34
# 3     10.70
# 4      8.92
# 5      8.57
# 6      5.82
# 7      4.59
# 8      3.85
# 9      3.30
# Name: emp_length, dtype: float64

# %%
countplot('term')
#Findings
#1. almost 75% loans are of lesser duration i.e. 36 months.
#2. long duration loans(60 months) are around 25%
# Out:
# 36    75.22
# 60    24.78
# Name: term, dtype: float64

# %%
#Bivariate Analysis
#For bivariate analysis we will be analysing each column with the loan status column as it is our target variable
def boxplot_bivariate(column):
    print(loan.groupby('loan_status')[column].describe())
    sns.boxplot(loan, y=column, x='loan_status')

# %%
#Loan Amount Vs Loan Status
boxplot_bivariate('loan_amnt')

#Findings
#1. Average loan amount of defaulter is slightly high
#2. There is no major difference in loan amounts of defaulters.
# Out:
#                count          mean          std     min     25%      50%  \
# loan_status
# 0            31497.0  10913.713211  7107.456760   500.0  5500.0   9600.0
# 1             5265.0  12331.524217  8023.430744  1000.0  6000.0  10000.0
#
#                  75%      max
# loan_status
# 0            15000.0  35000.0
# 1            17000.0  35000.0

# %%
boxplot_bivariate('int_rate')
#Findings
#1. Applicants with high interest rate seems to default more than lower interest rates.
# Out:
#                count       mean       std   min    25%    50%    75%    max
# loan_status
# 0            31497.0  11.626176  3.586208  5.42   8.59  11.49  13.99  24.11
# 1             5265.0  13.889795  3.639657  5.42  11.46  13.61  16.45  24.40

# %%
boxplot_bivariate('annual_inc')
#Findings
#1. Applicants with higher salary seem to default a little lesser.
# Out:
#                count          mean           std      min      25%      50%  \
# loan_status
# 0            31497.0  67315.156188  35206.963689  15085.0  42000.0  60000.0
# 1             5265.0  61542.192000  32533.124287  15090.0  39000.0  54288.0
#
#                  75%       max
# loan_status
# 0            84000.0  234996.0
# 1            75000.0  230000.0

# %%
boxplot_bivariate('emp_length')
#Findings
#1. Applicants with longer employement length seem to default higher.
# Out:
#                count      mean       std  min  25%  50%  75%   max
# loan_status
# 0            31497.0  5.051941  3.390973  1.0  2.0  4.0  9.0  10.0
# 1             5265.0  5.245774  3.444136  1.0  2.0  5.0  9.0  10.0

# %%
boxplot_bivariate('dti')

#Findings
#1. applicants with higher dti seems to default a little more.
# Out:
#                count       mean       std  min   25%    50%    75%    max
# loan_status
# 0            31497.0  13.258119  6.646771  0.0  8.15  13.32  18.49  29.99
# 1             5265.0  14.075812  6.546643  0.0  9.17  14.40  19.30  29.85

# %%
def barplot(column):
    group_wise_percentage = 100 * loan.groupby('loan_status')[column].value_counts() / loan.groupby('loan_status')[column].count()
    #print(round(group_wise_percentage, 2))
    sns.barplot(data=loan, y = 'loan_status', x = column)

# %%
barplot('term')
#Findings
#60 months loans default more than 36 months loans

# %%
barplot('grade')

#Findings
#Clearly, as the grade of loan goes from A to G, the default rate increases. 
#This is expected because the grade is decided by Lending Club based on the riskiness of the loan.

# %%
plt.xticks(rotation = 90)
barplot('sub_grade')

#Findings
#as expected - A1 is better than A2 better than A3 and so on

# %%
barplot('home_ownership')

#Findings
#home ownership: not a great discriminator

# %%
barplot('verification_status')
#Findings
#surprisingly, verified loans default more than not verified

# %%
barplot('issue_month')

#Findings
#1. not much variation across months

# %%
barplot('issue_year')

#Findings
#the default rate had suddenly increased in 2011, inspite of reducing from 2008 till 2010

# %%
plt.xticks(rotation=90)
barplot('purpose')

# %%
#Bivariate Analysis of continuous variables
def create_bins(n, ranges, labels):
    """
    Create bins of continuous variables based on the ranges provided

    ** param n: value
    ** ranges across which the value can exist
    ** labels that will be assigned based on the range of the value

    ## return - label according to the range of the value
    """
    for i in range(len(ranges)):
        if(n <= ranges[i]):
            return labels[i]
    
    return labels[-1]

# %%
loan['loan_amnt'] = loan['loan_amnt'].apply(lambda lm : create_bins(lm, [5000, 15000, 25000], ['low', 'medium', 'high', 'very high']))

# %%
barplot('loan_amnt')

#Findings
#higher the loan amount, higher the default rate

# %%
loan['funded_amnt_inv'] = loan['funded_amnt_inv'].apply(lambda lm : create_bins(lm, [5000, 15000, 25000], ['low', 'medium', 'high', 'very high']))

# %%
barplot('funded_amnt_inv')

#Findings
#higher the funded amount by investor, higher the default rate
#a little dip can be seen from low to medium though

# %%
loan['funded_amnt'] = loan['funded_amnt'].apply(lambda lm : create_bins(lm, [5000, 15000], ['low', 'medium', 'high']))

# %%
barplot('funded_amnt')
#Findings
#higher the funded amount, higher the default rate
#a little dip can be seen from low to medium though

# %%
loan['int_rate'] = loan['int_rate'].apply(lambda lm : create_bins(lm, [10, 15], ['low', 'medium', 'high']))

# %%
barplot('int_rate')
#Findings
#high interest rates default more, as expected

# %%
loan['dti'] = loan['dti'].apply(lambda lm : create_bins(lm, [10, 20], ['low', 'medium', 'high']))

# %%
barplot('dti')
#Findings
#high dti translates into higher default rates, as expected

# %%
loan['installment'] = loan['installment'].apply(lambda lm : create_bins(lm, [200, 400, 600], ['low', 'medium', 'high', 'very high']))

# %%
barplot('installment')
#Findings
#the higher the installment amount, the higher the default rate

# %%
loan['annual_inc'] = loan['annual_inc'].apply(lambda lm : create_bins(lm, [50000, 100000, 150000], ['low', 'medium', 'high', 'very high']))

# %%
barplot('annual_inc')
#Findings
#lower the annual income, higher the default rate

# %%
loan['emp_length'] = loan['emp_length'].apply(lambda lm : create_bins(lm, [1, 3, 7], ['fresher', 'junior', 'senior', 'expert']))

# %%
barplot('emp_length')

#Findings
#not much of a predictor of default

# %%
#Segmented univariate analysis
#We have now compared the default rates across various variables, and some of the important predictors are purpose of the loan, interest rate, annual income, grade etc.
#In the credit industry, one of the most important factors affecting default is the purpose of the loan - home loans perform differently than credit cards, credit cards are very different from debt condolidation loans etc.
#This comes from business understanding, though let's again have a look at the default rates across the purpose of the loan.

plt.xticks(rotation = 90)
barplot('purpose')

# %%
major_loan_purpose = ['debt_consolidation', 'credit_card', 'home_improvement', 'major_purchase']
loan = loan[loan['purpose'].isin(major_loan_purpose)]
loan['purpose'].value_counts()
# Out:
# debt_consolidation    17400
# credit_card            4832
# home_improvement       2696
# major_purchase         2030
# Name: purpose, dtype: int64

# %%
countplot('purpose')
# Out:
# debt_consolidation    64.54
# credit_card           17.92
# home_improvement      10.00
# major_purchase         7.53
# Name: purpose, dtype: float64

# %%
def barplot_segmented(column):
    sns.barplot(data = loan, x = column, y = 'loan_status', hue = 'purpose')
    plt.show()

# %%
barplot_segmented('term')

# %%
barplot_segmented('grade')

# %%
barplot_segmented('home_ownership')

# %%
barplot_segmented('issue_year')

# %%
barplot_segmented('emp_length')

# %%
barplot_segmented('loan_amnt')

# %%
barplot_segmented('int_rate')

# %%
barplot_segmented('installment')

# %%
barplot_segmented('dti')

# %%
barplot_segmented('annual_inc')

# %%
#In general we can see that the debt consolidation loans have the highest default rate. using the above plots.

def get_default_rates(categorycolumn):
    default_rates_average = loan.groupby(categorycolumn).loan_status.mean().sort_values(ascending = False)
    default_rates_diff = default_rates_average[0] - default_rates_average[-1]
    return (round(default_rates_average, 2), round(default_rates_diff, 2))

# %%
loan_categorical = loan.loc[ : , loan.dtypes == object]
loan_categorical['loan_status'] = loan['loan_status']

default_rate_dictionary = {key: get_default_rates(key)[1]*100 for key in loan_categorical.columns if key != 'loan_status'}
for key in default_rate_dictionary.keys():
    print(key, ':', default_rate_dictionary[key])
# Out:
# loan_amnt : 9.0
# funded_amnt : 6.0
# funded_amnt_inv : 7.000000000000001
# int_rate : 19.0
# installment : 3.0
# grade : 27.0
# sub_grade : 47.0
# emp_length : 2.0
# home_ownership : 16.0
# annual_inc : 6.0
# verification_status : 4.0
# purpose : 5.0
# dti : 5.0
